# %% [markdown]
# # Lab 4: Introduction to Python Environments
# ## Anaconda & Jupyter Notebook
#
# This lab introduces **Anaconda** and **JupyterLab/Notebook, which we will use throughout the course.

# %% [markdown]
# ## Learning Objectives
# - Launch Jupyter Notebook using Anaconda
# - Create and run Python code cells
# - Use basic Python syntax
# - Work with common Python data types

# %% [markdown]
# ## 🔹 Part I — Getting Started with Jupyter Notebook
# Jupyter notebooks are made of **cells**.
# - Code cells execute Python
# - Markdown cells contain text

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ## 🔹 Part II — Basic Python Syntax

# %%
# Printing output
print("Welcome to Python!")

# Variables
x = 10
y = 5

# Arithmetic
print(x + y)
print(x * y)
# Out:
# Welcome to Python!
# 15
# 50

# %% [markdown]
# ## 🔹 Part III — Python Data Types

# %%
# Numbers
a = 3
b = 2.5
print(a, b)

# Strings
name = "Student"
print("Hello,", name)

# Lists
nums = [1, 2, 3, 4]
print(nums)
# Out:
# 3 2.5
# Hello, Student
# [1, 2, 3, 4]

# %% [markdown]
# ## 🔹 Part IV — Input and Output

# %%
user = input("Enter your name: ")
print("Nice to meet you,", user)
# Out:
# Enter your name:  Abit Jurkuch
# Nice to meet you, Abit Jurkuch

# %% [markdown]
# ## Student Tasks
# Complete the tasks below.

# %% [markdown]
# ### Task 1 — Modify Output
# - Change the print statement to display your name.

# %%
print('My name is Michael Moriarty')
# Out:
# My name is Michael Moriarty

# %% [markdown]
# ### Task 2 — Variables
# - Create two numbers and print their sum and product.

# %%
x = 5
y = 10
print(x + y, x * y)
# Out:
# 15 50

# %% [markdown]
# ### Task 3 — Lists
# - Create a list of 5 numbers and print its length.

# %%
my_set = {333, 22, 1}
print(my_set)
# Out:
# {1, 333, 22}

# %% [markdown]
# ### Task 4 — Reflection
# - Add a Markdown cell explaining what Jupyter Notebook is.

# %%
Jupyter Notebook is an interactive coding environment used for coding in Python in separate cells. It is commonly used for students, data science experimentation, and prototyping due to it's ability to mix code with notes.
# Out:
#   Cell In[12], line 1
#     Jupyter Notebook is an interactive coding environment used for coding in Python in separate cells. It is commonly used for students, data science experimentation, and prototyping due to it's ability to mix code with notes.
#                                                                                                                                                                                                 ^
# SyntaxError: unterminated string literal (detected at line 1)
